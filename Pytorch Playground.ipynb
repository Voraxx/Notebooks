# %%
# !pip install torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %% [markdown]
# The neural network will have three layers: the input layer, the hidden layer, and the output layer. The input layer will have two nodes, one for x and one for y. The hidden layer will have 32 nodes, and the output layer will have one node. The output layer will produce a single output value that represents the neural network's prediction.
#
# We apply the ReLU function to the input layer and store the result in the hidden layer. The ReLU function will return the input if it's positive, and it will return zero if the input is negative.

# %% [markdown]
# The next step is to train the neural network. Training involves adjusting the weights of the connections between the nodes in the network so that it can produce accurate predictions.
#
# First, we'll need to define some random weights for the connections between the nodes in the neural network. We'll use a Python function called "random.randn" to generate random numbers with a normal distribution. Next, we'll define a loss function, which tells us how far off the predictions of the neural network are from the correct answers.
